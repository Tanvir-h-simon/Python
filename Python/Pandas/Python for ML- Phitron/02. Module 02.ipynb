# %%
raining = True

if raining == True:
    print("Rain coat is necessary")
else: 
    print("This is a sunny day")
# Out:
# Rain coat is necessary

# %%
taka = 1000

if (taka < 500):
    print("Hello")
elif (taka < 300):
    print("Hi")
elif (taka > 500):
    print("Hey")
else:
    print("No")
# Out:
# Hey

# %%
for i in range(1, 10):
    print("Hello")
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
count = 1

while count < 10:
    print("Hello")
    count = count + 1
print(count)
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# 10

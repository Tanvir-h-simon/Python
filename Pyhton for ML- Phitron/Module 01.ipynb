# %%
print("Hello world")
# Out:
# Hello world

# %%
age = 18
num = 45.5
name = "Tanvir"

print(type(age), type(num), type(name))
# Out:
# <class 'int'> <class 'float'> <class 'str'>

# %%
age = input("Age? ")

# print(age, type(age))

age = int(age)

print(age, type(age))
# Out:
# 15 <class 'int'>

# %%
x = int(input())
y = int(input())

print(x + y)
# Out:
# 15
